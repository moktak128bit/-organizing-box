# %%
#1 Object: 개체별 데이터셋 생성 및 분리.
#1 Detail: 한우와 홀스타인 데이터를 train/val로 분리하여 저장.
'''
hanwoo/
│  ├── annotations/          # XML 어노테이션 파일들
│  │   └── .xml
│  └── muzzle/
│      └── unit/
│          └── .jpg         # 이미지 파일들

holstein/
│  ├── annotations/          # XML 어노테이션 파일들
│  │   └── .xml
│  └── muzzle/
│      └── unit/
│          └── .jpg         # 이미지 파일들

datasets/
├── hanwoo/
│   ├── train/
│   │   ├── images/         # 학습용 이미지 파일들
│   │   └── labels/         # 학습용 라벨 파일들
│   └── val/
│       ├── images/         # 검증용 이미지 파일들
│       └── labels/         # 검증용 라벨 파일들
├── holstein/
    ├── train/
    │   ├── images/         # 학습용 이미지 파일들
    │   └── labels/         # 학습용 라벨 파일들
    └── val/
        ├── images/         # 검증용 이미지 파일들
        └── labels/         # 검증용 라벨 파일들
'''
import os
import random
import shutil
import xml.etree.ElementTree as ET
import re
from tqdm import tqdm  # 진행 상황 표시를 위한 라이브러리

#1-1 Object: YOLO 데이터셋 디렉토리 생성
#1-1 Detail: 한우와 홀스타인 데이터를 저장할 train/val 디렉토리 생성
BASE_DIR = r"F:\imageDB\cattleDB"  # 실제 데이터 경로로 변경
HANWOO_IMAGE_DIR = os.path.join(BASE_DIR, "hanwoo/muzzle")
HANWOO_ANNOTATION_DIR = os.path.join(BASE_DIR, "hanwoo/annotations")
HOLSTEIN_IMAGE_DIR = os.path.join(BASE_DIR, "holstein/muzzle")
HOLSTEIN_ANNOTATION_DIR = os.path.join(BASE_DIR, "holstein/annotations")
OUTPUT_DIR = os.path.join(BASE_DIR, "datasets")
CLASSES = ['muzzle']  # 클래스 목록

#1-1-1 YOLO 데이터셋 디렉토리 생성 함수
def create_dirs(base_output_dir, categories):
    for category in categories:
        os.makedirs(os.path.join(base_output_dir, category, "train/images"), exist_ok=True)
        os.makedirs(os.path.join(base_output_dir, category, "train/labels"), exist_ok=True)
        os.makedirs(os.path.join(base_output_dir, category, "val/images"), exist_ok=True)
        os.makedirs(os.path.join(base_output_dir, category, "val/labels"), exist_ok=True)

#1-1-2 디렉토리 생성
create_dirs(OUTPUT_DIR, ["hanwoo", "holstein"])  # 한우와 홀스타인 카테고리별로 디렉토리 생성
print("YOLO 데이터셋 디렉토리 생성 완료!")

#1-2 Object: XML -> YOLO 포맷 변환
#1-2 Detail: XML 어노테이션 파일을 YOLO 포맷으로 변환하여 .txt 라벨 파일을 생성
def convert_xml_to_yolo(xml_path, output_path, classes):
    try:
        tree = ET.parse(xml_path)
        root = tree.getroot()
        size = root.find('size')
        width = int(size.find('width').text)
        height = int(size.find('height').text)

        yolo_labels = []
        for obj in root.findall('object'):
            class_name = obj.find('name').text
            if class_name not in classes:
                continue
            class_id = classes.index(class_name)
            bndbox = obj.find('bndbox')
            xmin = int(bndbox.find('xmin').text)
            ymin = int(bndbox.find('ymin').text)
            xmax = int(bndbox.find('xmax').text)
            ymax = int(bndbox.find('ymax').text)

            # YOLO 포맷으로 변환 (정규화)
            x_center = (xmin + xmax) / 2.0 / width
            y_center = (ymin + ymax) / 2.0 / height
            w = (xmax - xmin) / float(width)
            h = (ymax - ymin) / float(height)
            yolo_labels.append(f"{class_id} {x_center} {y_center} {w} {h}")

        if yolo_labels:
            with open(output_path, 'w') as f:
                f.write("\n".join(yolo_labels))
        else:
            print(f"Warning: {xml_path}에는 라벨이 없습니다.")
    except FileNotFoundError:
        print(f"Error: XML 파일 {xml_path}을 찾을 수 없습니다.")
    except ET.ParseError:
        print(f"Error: {xml_path} 파일 파싱 중 오류 발생.")
    except Exception as e:
        print(f"Error converting {xml_path} to YOLO format: {e}")

#1-3 Object: 이미지 파일 목록 생성 및 XML 파일 매칭
#1-3 Detail: 이미지 파일을 찾고, 각 이미지에 매칭되는 XML 파일을 확인하여 처리
def convert_xml_to_yolo(xml_path, output_path, classes):
    """
    XML 파일을 YOLO 포맷으로 변환하여 .txt 라벨 파일을 생성
    """
    try:
        tree = ET.parse(xml_path)
        root = tree.getroot()

        # 이미지 크기 가져오기
        size = root.find('size')
        width = int(size.find('width').text)
        height = int(size.find('height').text)

        yolo_labels = []

        # 'muzzle' 클래스 처리
        for obj in root.findall('object'):
            class_name = obj.find('name').text.strip()  # 객체 이름을 추출

            # 원래 클래스 이름을 'muzzle'로 바꿈
            if class_name != 'muzzle':
                class_name = 'muzzle'  # 여기서 'muzzle'로 바꿔줌
            
            class_id = classes.index(class_name)  # 'muzzle'은 클래스 0
            bndbox = obj.find('bndbox')
            xmin = int(bndbox.find('xmin').text)
            ymin = int(bndbox.find('ymin').text)
            xmax = int(bndbox.find('xmax').text)
            ymax = int(bndbox.find('ymax').text)

            # YOLO 포맷으로 변환 (정규화)
            x_center = (xmin + xmax) / 2.0 / width
            y_center = (ymin + ymax) / 2.0 / height
            w = (xmax - xmin) / float(width)
            h = (ymax - ymin) / float(height)
            yolo_labels.append(f"{class_id} {x_center} {y_center} {w} {h}")

        if yolo_labels:
            with open(output_path, 'w') as f:
                f.write("\n".join(yolo_labels))
        else:
            print(f"Warning: {xml_path}에는 'muzzle' 클래스가 없거나 라벨이 없습니다.")
    except FileNotFoundError:
        print(f"Error: XML 파일 {xml_path}을 찾을 수 없습니다.")
    except ET.ParseError:
        print(f"Error: {xml_path} 파일 파싱 중 오류 발생.")
    except Exception as e:
        print(f"Error converting {xml_path} to YOLO format: {e}")

 #1-3-1 이미지 파일 목록 생성 함수
def get_image_files(image_dir):
    image_files = []
    for folder in os.listdir(image_dir):
        folder_path = os.path.join(image_dir, folder)
        if os.path.isdir(folder_path):
            for img in os.listdir(folder_path):
                if img.endswith('.jpg'):
                    image_files.append(os.path.join(folder_path, img))
    return image_files

def split_and_convert_data(image_dir, annotation_dir, output_dir, category, classes, train_ratio=0.8):
    train_image_dir = os.path.join(output_dir, category, "train/images")
    train_label_dir = os.path.join(output_dir, category, "train/labels")
    val_image_dir = os.path.join(output_dir, category, "val/images")
    val_label_dir = os.path.join(output_dir, category, "val/labels")

    image_files = get_image_files(image_dir)
    random.shuffle(image_files)
    split_idx = int(len(image_files) * train_ratio)
    train_images = image_files[:split_idx]
    val_images = image_files[split_idx:]

    # train 데이터 처리
    for img_path in tqdm(train_images, desc=f"Processing {category} train data"):
        img_name = os.path.basename(img_path)
        xml_file = find_matching_xml(img_name, annotation_dir)

        if xml_file:
            xml_path = os.path.join(annotation_dir, xml_file)
            output_label_path = os.path.join(train_label_dir, os.path.splitext(img_name)[0] + '.txt')
            if os.path.exists(xml_path) and xml_path.endswith('.xml'):
                try:
                    shutil.copy(img_path, train_image_dir)  # 이미지 복사
                    print(f"Copying {img_path} to {train_image_dir}")  # 디버깅 출력
                    convert_xml_to_yolo(xml_path, output_label_path, classes)
                except Exception as e:
                    print(f"Error processing {img_path}: {e}")
            else:
                print(f"Warning: {xml_path}가 없거나 형식이 올바르지 않습니다.")
        else:
            print(f"Warning: {img_path}에 해당하는 XML 파일을 찾을 수 없습니다.")
            
#1-4 Object: 이미지 파일과 XML 파일 매칭 (더욱 robust하게)
#1-4 Detail: 이미지 이름을 기반으로 가장 적합한 XML 파일을 찾음
def find_matching_xml(image_name, annotation_dir):
    image_base_name = os.path.splitext(image_name)[0]
    best_match = None
    max_similarity = 0

    for xml_file in os.listdir(annotation_dir):
        if not xml_file.endswith('.xml'):
            continue
        xml_base_name = os.path.splitext(xml_file)[0]
        similarity = len(re.findall(r'\d+', image_base_name))  # 숫자 부분만 비교
        if similarity > max_similarity:
            max_similarity = similarity
            best_match = xml_file
    return best_match

#1-5 Object: 데이터 분리 및 변환
#1-5 Detail: 이미지를 train/val로 분리하고, YOLO 포맷으로 변환하여 저장
def split_and_convert_data(image_dir, annotation_dir, output_dir, category, classes, train_ratio=0.8):
    train_image_dir = os.path.join(output_dir, category, "train/images")
    train_label_dir = os.path.join(output_dir, category, "train/labels")
    val_image_dir = os.path.join(output_dir, category, "val/images")
    val_label_dir = os.path.join(output_dir, category, "val/labels")

    image_files = get_image_files(image_dir)
    random.shuffle(image_files)
    split_idx = int(len(image_files) * train_ratio)
    train_images = image_files[:split_idx]
    val_images = image_files[split_idx:]

    # train 데이터 처리
    for img_path in tqdm(train_images, desc=f"Processing {category} train data"):  # 진행 상태 표시
        img_name = os.path.basename(img_path)
        xml_file = find_matching_xml(img_name, annotation_dir)

        if xml_file:
            xml_path = os.path.join(annotation_dir, xml_file)
            output_label_path = os.path.join(train_label_dir, os.path.splitext(img_name)[0] + '.txt')
            if os.path.exists(xml_path) and xml_path.endswith('.xml'):
                try:
                    shutil.copy(img_path, train_image_dir)
                    convert_xml_to_yolo(xml_path, output_label_path, classes)
                except Exception as e:
                    print(f"Error processing {img_path}: {e}")
            else:
                print(f"Warning: {xml_path}가 없거나 형식이 올바르지 않습니다. {img_path}에 매칭되는 xml파일을 확인해주세요.")
        else:
            print(f"Warning: {img_path}에 해당하는 XML 파일을 찾을 수 없습니다.")

    # val 데이터 처리
    for img_path in tqdm(val_images, desc=f"Processing {category} val data"):  # 진행 상태 표시
        img_name = os.path.basename(img_path)
        xml_file = find_matching_xml(img_name, annotation_dir)

        if xml_file:
            xml_path = os.path.join(annotation_dir, xml_file)
            output_label_path = os.path.join(val_label_dir, os.path.splitext(img_name)[0] + '.txt')
            if os.path.exists(xml_path) and xml_path.endswith('.xml'):
                try:
                    shutil.copy(img_path, val_image_dir)
                    convert_xml_to_yolo(xml_path, output_label_path, classes)
                except Exception as e:
                    print(f"Error processing {img_path}: {e}")
            else:
                print(f"Warning: {xml_path}가 없거나 형식이 올바르지 않습니다. {img_path}에 매칭되는 xml파일을 확인해주세요.")
        else:
            print(f"Warning: {img_path}에 해당하는 XML 파일을 찾을 수 없습니다.")

#1-6 실행
create_dirs(OUTPUT_DIR, ["hanwoo", "holstein"])

split_and_convert_data(HANWOO_IMAGE_DIR, HANWOO_ANNOTATION_DIR, OUTPUT_DIR, "hanwoo", CLASSES)
split_and_convert_data(HOLSTEIN_IMAGE_DIR, HOLSTEIN_ANNOTATION_DIR, OUTPUT_DIR, "holstein", CLASSES)

#1-7 완료 메시지 출력
print("한우 및 홀스타인 데이터 train/val 분리 완료!")
# Out:
# YOLO 데이터셋 디렉토리 생성 완료!
# Processing hanwoo train data:  27%|██▋       | 2010/7462 [02:49<05:15, 17.26it/s]

# %%
#2 Object: YOLO 데이터 구성 파일 생성.
#2 Detail: YOLOv8 학습에 필요한 data.yaml 파일 생성.

import os

#2-1 data.yaml 파일 내용 정의
data_yaml_content = f"""
train: F:/imageDB/cattleDB/datasets/hanwoo/train/images  # 학습 이미지 경로
val: F:/imageDB/cattleDB/datasets/hanwoo/val/images      # 검증 이미지 경로

nc: 1  # 클래스 수 (비문)
names: ['muzzle']  # 클래스 이름
"""

#2-2 data.yaml 파일 저장 경로 설정
data_yaml_path = r"F:/imageDB/cattleDB/datasets/data.yaml"

#2-3 data.yaml 파일 생성
with open(data_yaml_path, 'w') as yaml_file:
    yaml_file.write(data_yaml_content)

#2-4 확인 메시지 출력
print(f"data.yaml 파일 생성 완료! 경로: {data_yaml_path}")
# Out:
# data.yaml 파일 생성 완료! 경로: F:/imageDB/cattleDB/datasets/data.yaml

# %%
#3 Object: YOLOv8 모델 학습
#3 Detail: 준비된 데이터로 YOLOv8 모델 학습 수행

#3-1 데이터셋 구성 파일 경로 설정
# data.yaml 파일의 경로를 설정합니다.
data_yaml_path = r"F:/imageDB/cattleDB/datasets/data.yaml"  # data.yaml 파일 경로

#3-2 YOLOv8 모델 초기화
# YOLOv8 모델을 Nano 버전으로 초기화합니다. (경량 모델)
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # YOLOv8 Nano 버전 (경량 모델)

#3-3 YOLOv8 모델 학습 수행
# 학습을 위해 YOLOv8 모델을 학습시킵니다. data.yaml 경로와 학습 파라미터를 설정합니다.
model.train(
    data=data_yaml_path,  # data.yaml 파일 경로
    epochs=20,             # 학습 에포크 수
    batch=16,              # 배치 크기
    imgsz=640,             # 입력 이미지 크기
    save=True,             # 모델 학습 결과 저장
    project="runs/train",  # 학습 결과 저장 위치
    name="muzzle_detector"  # 프로젝트 이름
)

#3-4 학습 완료 메시지 출력
print("YOLOv8 모델 학습 완료!")
# Out:
# New https://pypi.org/project/ultralytics/8.3.55 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.155  Python-3.11.9 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=F:/imageDB/cattleDB/datasets/data.yaml, epochs=20, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=runs/train, name=muzzle_detector, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs\train\muzzle_detector3
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# Model summary: 225 layers, 3011043 parameters, 3011027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs\train\muzzle_detector3', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed
# train: Scanning F:\imageDB\cattleDB\datasets\hanwoo\train\labels... 8921 images, 1860 backgrounds, 0 corrupt: 100%|██████████| 9319/9319 [08:21<00:00, 18.58it/s]
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M1.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M10.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M11.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M12.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M13.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M14.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M15.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M16.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M17.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M18.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M19.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M2.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M20.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M21.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M22.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M23.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M24.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M25.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M26.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M27.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M28.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M29.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M3.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M30.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M31.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M32.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M33.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M34.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M35.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M36.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M37.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M38.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M39.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M4.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M40.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M5.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M6.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M7.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M8.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002009148520_M9.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M1.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M10.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M11.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M12.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M13.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M14.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M15.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M16.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M17.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M18.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M19.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M2.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M20.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M21.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M3.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M4.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M5.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M6.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M7.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M8.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002038129217_M9.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M1.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M10.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M11.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M12.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M13.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M14.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M15.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M16.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M17.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M18.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M19.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M2.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M20.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M21.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M22.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M23.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M24.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M25.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M26.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M27.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M28.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M29.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M3.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M4.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M5.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M6.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M7.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M8.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002069691633_M9.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070435220_M1.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070435220_M10.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070435220_M11.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070435220_M12.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070435220_M13.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070435220_M14.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070435220_M15.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070435220_M16.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070435220_M17.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070435220_M2.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070435220_M3.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070435220_M4.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070435220_M5.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070435220_M6.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070435220_M7.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070435220_M8.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070435220_M9.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070699886_M16.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070699886_M17.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070699886_M18.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070699886_M19.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070699886_M20.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070699886_M21.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070699886_M22.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002070699886_M24.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M1.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M10.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M11.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M12.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M13.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M14.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M15.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M16.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M17.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M18.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M2.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M3.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M4.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M5.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M6.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M7.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M8.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521619_M9.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M10.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M11.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M12.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M13.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M14.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M15.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M16.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M17.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M18.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M19.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M20.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M21.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M22.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M23.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M24.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M25.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M26.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M27.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M28.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M29.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M30.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M31.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M32.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M33.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M34.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002071521678_M9.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M1.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M10.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M11.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M12.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M13.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M14.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M15.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M16.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M17.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M18.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M19.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M2.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M20.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M21.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M22.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M23.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M24.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M25.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M26.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M27.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M28.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M29.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M3.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M30.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M31.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M32.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M33.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M34.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M4.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M5.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M6.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M7.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M8.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002073425078_M9.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M10.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M11.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M12.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M13.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M14.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M15.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M16.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M17.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M18.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M19.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M20.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M21.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M22.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M23.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M24.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M25.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M26.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M27.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M28.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M29.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002078494490_M9.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002080591493_M1.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002080591493_M10.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002080591493_M11.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002080591493_M12.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002080591493_M13.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002080591493_M14.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002080591493_M2.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002080591493_M3.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002080591493_M4.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002080591493_M5.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002080591493_M6.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002080591493_M7.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002080591493_M8.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002080591493_M9.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002083965915_M10.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002083965915_M11.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002083965915_M12.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002083965915_M13.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002083965915_M9.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002083966022_M10.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002083966022_M11.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002083966022_M12.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002083966022_M13.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002083966022_M14.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002083966022_M9.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002084592564_M19.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002084592564_M20.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002084592564_M21.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002084592564_M22.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002084592564_M24.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002084592564_M25.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002084592564_M26.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002084592564_M27.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002084592564_M28.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002084592564_M29.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002084592564_M30.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002084592564_M31.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002084592564_M32.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002084592564_M33.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085199053_M1.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085199053_M2.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085199053_M3.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085199053_M4.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085199053_M5.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085199053_M6.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085199053_M7.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085199053_M8.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085199053_M9.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M1.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M10.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M11.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M12.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M13.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M14.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M15.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M16.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M17.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M18.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M19.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M2.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M20.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M21.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M22.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M23.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M24.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M25.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M26.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M27.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M28.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M3.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M4.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M5.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M6.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M7.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M8.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999053_M9.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M10.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M11.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M12.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M13.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M14.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M15.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M16.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M17.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M18.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M19.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M20.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M21.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M22.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M23.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M24.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M25.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M26.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M27.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002085999238_M9.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M1.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M10.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M11.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M12.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M13.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M14.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M15.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M16.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M17.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M18.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M19.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M2.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M20.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M21.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M22.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M23.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M24.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M25.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M26.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M27.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M28.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M29.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M3.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M30.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M31.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M4.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M5.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M6.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M7.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M8.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088032589_M9.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M1.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M10.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M11.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M12.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M13.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M14.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M15.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M16.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M17.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M18.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M19.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M2.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M20.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M21.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M22.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M23.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M24.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M25.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M26.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M27.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M28.jpg: corrupt JPEG restored and saved
# train: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\train\images\002088037752_M29.jpg: corrupt JPEG restored and saved
# ...
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002312385129_M30.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002312385129_M32.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002312385129_M8.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002312385129_M9.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M12.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M13.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M14.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M16.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M17.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M18.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M19.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M20.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M21.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M22.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M23.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M29.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M30.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M31.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M32.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M33.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M34.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061458_M9.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061659_M10.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061659_M12.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061659_M14.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061659_M15.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061659_M16.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061659_M19.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061659_M20.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061659_M21.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061659_M23.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061659_M24.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061659_M27.jpg: corrupt JPEG restored and saved
# val: WARNING  F:\imageDB\cattleDB\datasets\hanwoo\val\images\002313061659_M28.jpg: corrupt JPEG restored and saved
# val: New cache created: F:\imageDB\cattleDB\datasets\hanwoo\val\labels.cache
# Plotting labels to runs\train\muzzle_detector3\labels.jpg...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs\train\muzzle_detector3
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      2.35G      1.375      2.312      1.448         17        640: 100%|██████████| 583/583 [17:25<00:00,  1.79s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [23:10<00:00,  7.06s/it]
#                    all       6300       1866      0.234      0.655      0.231      0.157
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      2.37G      1.103      1.443      1.202          7        640: 100%|██████████| 583/583 [16:59<00:00,  1.75s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [21:02<00:00,  6.41s/it]
#                    all       6300       1866      0.241      0.572      0.237      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      2.37G      1.002      1.261      1.147         15        640: 100%|██████████| 583/583 [15:25<00:00,  1.59s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [21:42<00:00,  6.61s/it]
#                    all       6300       1866      0.273      0.703      0.275      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      2.37G     0.8925      1.142      1.096          9        640: 100%|██████████| 583/583 [16:16<00:00,  1.68s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [22:31<00:00,  6.86s/it]
#                    all       6300       1866      0.272      0.767      0.276      0.235
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      2.37G     0.8239      1.066      1.063         11        640: 100%|██████████| 583/583 [15:29<00:00,  1.59s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [34:45<00:00, 10.59s/it]
#                    all       6300       1866      0.273      0.732      0.279      0.261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      2.37G     0.7557     0.9903      1.035         13        640: 100%|██████████| 583/583 [18:02<00:00,  1.86s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/197 [00:00<?, ?it/s]WARNING  NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [28:06<00:00,  8.56s/it]
#                    all       6300       1866      0.271        0.8      0.283      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      2.36G     0.7215       0.96      1.023         11        640: 100%|██████████| 583/583 [11:38<00:00,  1.20s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [08:34<00:00,  2.61s/it]
#                    all       6300       1866      0.284      0.931      0.291      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      2.37G     0.6828     0.9276      1.013         12        640: 100%|██████████| 583/583 [14:15<00:00,  1.47s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [25:23<00:00,  7.73s/it]
#                    all       6300       1866      0.289      0.806      0.292      0.286
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      2.37G     0.6579     0.8938     0.9999         14        640: 100%|██████████| 583/583 [09:17<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [26:44<00:00,  8.14s/it]
#                    all       6300       1866      0.292       0.89      0.296      0.286
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20      2.37G     0.6307     0.8685      0.993         16        640: 100%|██████████| 583/583 [12:22<00:00,  1.27s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  35%|███▌      | 69/197 [07:00<01:59,  1.07it/s]WARNING  NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  36%|███▌      | 70/197 [07:15<10:39,  5.04s/it]WARNING  NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  36%|███▌      | 71/197 [07:33<18:57,  9.02s/it]WARNING  NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  37%|███▋      | 72/197 [07:48<22:26, 10.77s/it]WARNING  NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  37%|███▋      | 73/197 [08:00<23:22, 11.31s/it]WARNING  NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  38%|███▊      | 75/197 [08:22<22:49, 11.22s/it]WARNING  NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [19:32<00:00,  5.95s/it]
#                    all       6300       1866      0.276      0.888      0.283      0.278
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      2.36G     0.4942     0.7929     0.9778          6        640: 100%|██████████| 583/583 [16:05<00:00,  1.66s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [34:02<00:00, 10.37s/it]
#                    all       6300       1866       0.28       0.86      0.297      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      2.37G     0.4354     0.7355      0.952          4        640: 100%|██████████| 583/583 [16:42<00:00,  1.72s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [34:52<00:00, 10.62s/it]
#                    all       6300       1866      0.284      0.919      0.286      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      2.37G     0.4203     0.7081     0.9418          6        640: 100%|██████████| 583/583 [16:22<00:00,  1.69s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [25:12<00:00,  7.68s/it]
#                    all       6300       1866      0.291      0.913      0.293      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      2.37G     0.4023      0.681     0.9344          7        640: 100%|██████████| 583/583 [19:30<00:00,  2.01s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/197 [00:00<?, ?it/s]WARNING  NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   1%|          | 1/197 [00:11<36:28, 11.16s/it]WARNING  NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  22%|██▏       | 43/197 [03:49<02:00,  1.28it/s]WARNING  NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  22%|██▏       | 44/197 [04:03<12:11,  4.78s/it]WARNING  NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  23%|██▎       | 45/197 [04:19<20:48,  8.21s/it]WARNING  NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [20:16<00:00,  6.18s/it]
#                    all       6300       1866      0.291      0.943      0.293      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      2.36G     0.3916     0.6708     0.9358          6        640: 100%|██████████| 583/583 [15:15<00:00,  1.57s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [20:38<00:00,  6.29s/it]
#                    all       6300       1866      0.291      0.967      0.296      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      2.37G     0.3778     0.6503     0.9293          6        640: 100%|██████████| 583/583 [16:45<00:00,  1.72s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [27:17<00:00,  8.31s/it]
#                    all       6300       1866      0.291      0.966      0.294      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      2.37G     0.3736     0.6412     0.9298          6        640: 100%|██████████| 583/583 [16:47<00:00,  1.73s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [34:31<00:00, 10.51s/it]
#                    all       6300       1866      0.287      0.967      0.289      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      2.37G     0.3483     0.6172     0.9158          7        640: 100%|██████████| 583/583 [14:59<00:00,  1.54s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [20:38<00:00,  6.29s/it]
#                    all       6300       1866      0.291      0.976      0.295      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      2.36G     0.3367     0.6103     0.9147          5        640: 100%|██████████| 583/583 [15:16<00:00,  1.57s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [34:10<00:00, 10.41s/it]
#                    all       6300       1866      0.292      0.984      0.296      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      2.37G     0.3228     0.5944     0.9086          6        640: 100%|██████████| 583/583 [15:10<00:00,  1.56s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [40:36<00:00, 12.37s/it]
#                    all       6300       1866       0.29      0.983      0.295      0.295
#
# 20 epochs completed in 13.963 hours.
# Optimizer stripped from runs\train\muzzle_detector3\weights\last.pt, 6.2MB
# Optimizer stripped from runs\train\muzzle_detector3\weights\best.pt, 6.2MB
#
# Validating runs\train\muzzle_detector3\weights\best.pt...
# Ultralytics YOLOv8.0.155  Python-3.11.9 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 197/197 [35:12<00:00, 10.72s/it]
#                    all       6300       1866       0.28       0.86      0.297      0.296
# Speed: 0.5ms preprocess, 1.0ms inference, 0.0ms loss, 55.2ms postprocess per image
# Results saved to runs\train\muzzle_detector3
# YOLOv8 모델 학습 완료!

# %%
#검정

import pandas as pd

# CSV 파일 경로 설정
csv_file_path = r"C:\Users\tj\Desktop\runs\train\muzzle_detector3\results.csv"

# CSV 파일 읽기
results_df = pd.read_csv(csv_file_path)

# 열 이름에서 공백 제거
results_df.columns = results_df.columns.str.strip()

# 마지막 epoch에서의 주요 성능 지표 출력
last_epoch = results_df.iloc[-1]

# 수정된 열 이름을 사용하여 성능 지표 출력
print(f"Final Epoch: {last_epoch['epoch']}")
print(f"Final Precision: {last_epoch['metrics/precision(B)']}")
print(f"Final Recall: {last_epoch['metrics/recall(B)']}")
print(f"Final mAP@0.5: {last_epoch['metrics/mAP50(B)']}")
print(f"Final mAP@0.5:0.95: {last_epoch['metrics/mAP50-95(B)']}")
# Out:
# Final Epoch: 19.0
# Final Precision: 0.2899
# Final Recall: 0.98285
# Final mAP@0.5: 0.29503
# Final mAP@0.5:0.95: 0.29503

# %%
# Out:
# Ultralytics YOLOv8.0.155  Python-3.11.9 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 12675 gradients, 8.1 GFLOPs
#
# Dataset 'coco.yaml' images not found , missing path 'C:\Users\tj\Desktop\vsc\ubuntu\1workspace\win_server\datasets\coco\val2017.txt'
# Downloading https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017labels-segments.zip to 'C:\Users\tj\Desktop\vsc\ubuntu\1workspace\win_server\datasets\coco2017labels-segments.zip'...
# 100%|██████████| 169M/169M [00:15<00:00, 11.2MB/s]
# Unzipping C:\Users\tj\Desktop\vsc\ubuntu\1workspace\win_server\datasets\coco2017labels-segments.zip to C:\Users\tj\Desktop\vsc\ubuntu\1workspace\win_server\datasets...: 100%|██████████| 122232/122232 [01:23<00:00, 1460.37file/s]
# Downloading http://images.cocodataset.org/zips/train2017.zip to 'C:\Users\tj\Desktop\vsc\ubuntu\1workspace\win_server\datasets\coco\images\train2017.zip'...
# Downloading http://images.cocodataset.org/zips/test2017.zip to 'C:\Users\tj\Desktop\vsc\ubuntu\1workspace\win_server\datasets\coco\images\test2017.zip'...
# Downloading http://images.cocodataset.org/zips/val2017.zip to 'C:\Users\tj\Desktop\vsc\ubuntu\1workspace\win_server\datasets\coco\images\val2017.zip'...
#  Download failure, retrying 1/3 http://images.cocodataset.org/zips/train2017.zip...
#  Download failure, retrying 2/3 http://images.cocodataset.org/zips/train2017.zip...
#  Download failure, retrying 3/3 http://images.cocodataset.org/zips/train2017.zip...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\utils\downloads.py:256, in safe_download(url, file, dir, unzip, delete, curl, retry, min_bytes, progress)
#     255     r = subprocess.run(['curl', '-#', f'-{s}L', url, '-o', f, '--retry', '3', '-C', '-']).returncode
# --> 256     assert r == 0, f'Curl return value {r}'
#     257 else:  # urllib download
#
# AssertionError: Curl return value 23
#
# The above exception was the direct cause of the following exception:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 results = model.val()
#       2 print(f"Final precision: {results.pf_precision}")
#       3 print(f"Final recall: {results.pf_recall}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\engine\model.py:297, in Model.val(self, data, validator, **kwargs)
#     294 args.imgsz = check_imgsz(args.imgsz, max_dim=1)
#     296 validator = validator(args=args, _callbacks=self.callbacks)
# --> 297 validator(model=self.model)
#     298 self.metrics = validator.metrics
#     300 return validator.metrics
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\engine\validator.py:147, in BaseValidator.__call__(self, trainer, model)
#     144     LOGGER.info(f'Forcing batch=1 square inference (1,3,{imgsz},{imgsz}) for non-PyTorch models')
#     146 if isinstance(self.args.data, str) and self.args.data.split('.')[-1] in ('yaml', 'yml'):
# --> 147     self.data = check_det_dataset(self.args.data)
#     148 elif self.args.task == 'classify':
#     149     self.data = check_cls_dataset(self.args.data, split=self.args.split)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\data\utils.py:269, in check_det_dataset(dataset, autodownload)
#     267     r = os.system(s)
#     268 else:  # python script
# --> 269     exec(s, {'yaml': data})
#     270 dt = f'({round(time.time() - t, 1)}s)'
#     271 s = f"success ✅ {dt}, saved to {colorstr('bold', DATASETS_DIR)}" if r in (0, None) else f'failure {dt} ❌'
#
# File <string>:14
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\utils\downloads.py:362, in download(url, dir, unzip, delete, curl, threads, retry)
#     360 if threads > 1:
#     361     with ThreadPool(threads) as pool:
# --> 362         pool.map(
#     363             lambda x: safe_download(
#     364                 url=x[0], dir=x[1], unzip=unzip, delete=delete, curl=curl, retry=retry, progress=threads <= 1),
#     365             zip(url, repeat(dir)))
#     366         pool.close()
#     367         pool.join()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\pool.py:125, in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\pool.py:48, in mapstar(args)
#      47 def mapstar(args):
# ---> 48     return list(map(*args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\utils\downloads.py:363, in download.<locals>.<lambda>(x)
#     360 if threads > 1:
#     361     with ThreadPool(threads) as pool:
#     362         pool.map(
# --> 363             lambda x: safe_download(
#     364                 url=x[0], dir=x[1], unzip=unzip, delete=delete, curl=curl, retry=retry, progress=threads <= 1),
#     365             zip(url, repeat(dir)))
#     366         pool.close()
#     367         pool.join()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\utils\downloads.py:283, in safe_download(url, file, dir, unzip, delete, curl, retry, min_bytes, progress)
#     281                 raise ConnectionError(emojis(f'❌  Download failure for {url}. Environment is not online.')) from e
#     282             elif i >= retry:
# --> 283                 raise ConnectionError(emojis(f'❌  Download failure for {url}. Retry limit reached.')) from e
#     284             LOGGER.warning(f'⚠️ Download failure, retrying {i + 1}/{retry} {url}...')
#     286 if unzip and f.exists() and f.suffix in ('', '.zip', '.tar', '.gz'):
#
# ConnectionError:   Download failure for http://images.cocodataset.org/zips/train2017.zip. Retry limit reached.

# %%
# Out:
#   Cell In[28], line 1
#     tensorboard --logdir=runs/train/muzzle_detector
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?
